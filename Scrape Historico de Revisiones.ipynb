# %%
import pandas as pd

# %%
df2022=pd.read_csv('2022.1.1-2022.12.31',index_col=0)
df2021=pd.read_csv('2021.1.1-2021.12.31',index_col=0)
df2020=pd.read_csv('2020.1.1-2020.12.31',index_col=0)
df2019=pd.read_csv('2019.1.1-2019.12.31',index_col=0)
df2018=pd.read_csv('2018.1.1-2018.12.31',index_col=0)
df2017=pd.read_csv('2017.1.1-2017.12.31',index_col=0)
df2016=pd.read_csv('2016.1.1-2016.12.31',index_col=0)
df2015=pd.read_csv('2015.1.1-2015.12.31',index_col=0)
df2014=pd.read_csv('2014.1.1-2014.12.31',index_col=0)
planillas=pd.concat([df2022,df2021,df2020,df2019,df2018,df2017,df2016,df2015,df2014])

# %%
planillas['Fecha']=pd.to_datetime(planillas['Fecha'])

# %%
planillas
# Out:
#               Fecha Inicio hora_Resultado    Fin Tipo Uso Categoría  \
# Planilla
# 1153444  2022-03-01  07:37          08:03  08:03    P   X        UP
# 1153445  2022-03-01  07:38          08:02  08:02    L   P        M1
# 1153446  2022-03-01  07:42          08:13  08:29    P   X        UP
# 1153447  2022-03-01  08:01          08:12  08:29    P   X        UP
# 1153448  2022-03-01  08:10          08:34  09:02    P   X        UP
# ...             ...    ...            ...    ...  ...  ..       ...
# 1004189  2014-12-31  11:30          11:38  11:38    P   X        UP
# 1004190  2014-12-31  11:33          11:48  11:49    P   X        UP
# 1004191  2014-12-31  11:33          11:51  11:52    P   X        UP
# 1004192  2014-12-31  11:47          12:03  12:03    P   X        UP
# 1004193  2014-12-31  11:51          11:58  11:58    P   X        UP
#
#          Certificado       Vence  Dominio    Resultado          CUIT  \
# Planilla
# 1153444          NaN  03/03/2022   GXW345  Condicional  2.288276e+07
# 1153445     A 847051  03/07/2022  AC619BK         Apto  2.017596e+10
# 1153446     E 713352  03/01/2024  AA430OE         Apto  1.067453e+07
# 1153447     E 713351  03/01/2023   LTR244         Apto  1.849389e+07
# 1153448     E 713353  03/01/2024  AB588SJ         Apto  9.389511e+07
# ...              ...         ...      ...          ...           ...
# 1004189     B 968832  31/12/2016   KPV742         Apto  1.390194e+07
# 1004190     B 968833  31/12/2015   EIK358         Apto  2.482684e+07
# 1004191     B 968834  31/12/2016   JHP768         Apto  4.834391e+06
# 1004192     B 968836  31/12/2016   IET665         Apto  3.447823e+07
# 1004193     B 968835  31/12/2015   BRK784         Apto  3.021495e+07
#
#                         Razón Social  Línea
# Planilla
# 1153444          LUQUE, ADAN PAULINO      2
# 1153445   RASTELLINI CARLOS NORBERTO      1
# 1153446         GONZALEZ, LUIS OSCAR      2
# 1153447         GIMENEZ, DORA GLADYS      1
# 1153448              RIVAS, CLEMENTE      2
# ...                              ...    ...
# 1004189         PEDRINI, JUAN MANUEL      1
# 1004190          LOPEZ, FABIANA INES      1
# 1004191    DESSIMOZ, MARTHA ADELAIDA      1
# 1004192   DELLAMEA, NOELIA ALEJANDRA      1
# 1004193         VILLALBA, MARIO ALDO      1
#
# [176857 rows x 14 columns]

# %%
planillas.nunique()
# Out:
# Fecha               2407
# Inicio               763
# hora_Resultado       769
# Fin                  771
# Tipo                   4
# Uso                    4
# Categoría             10
# Certificado       146817
# Vence               3638
# Dominio            82247
# Resultado              4
# CUIT               60843
# Razón Social       61337
# Línea                  2
# dtype: int64

# %%
planillas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 176857 entries, 1153444 to 1004193
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Fecha           176857 non-null  datetime64[ns]
#  1   Inicio          176857 non-null  object
#  2   hora_Resultado  176857 non-null  object
#  3   Fin             176857 non-null  object
#  4   Tipo            176857 non-null  object
#  5   Uso             176857 non-null  object
#  6   Categoría       175232 non-null  object
#  7   Certificado     146820 non-null  object
#  8   Vence           176314 non-null  object
#  9   Dominio         176857 non-null  object
#  10  Resultado       176857 non-null  object
#  11  CUIT            175162 non-null  float64
#  12  Razón Social    175144 non-null  object
#  13  Línea           176857 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(11)
# memory usage: 20.2+ MB

# %% [markdown]
# Escribir a csv

# %%
planillas.to_csv('Lista_planillas_COMPLETE.csv')

# %% [markdown]
# # Importar librerias

# %%
import time

# %%
import requests

# %%
from tqdm.notebook import tqdm

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# # Definir funciones

# %% [markdown]
# Request Historico de Revisiones

# %%
def get_detalles(Patente):#input is in string format 
    global soup
    url = "https://rto.cent.gov.ar/rto/RTO/buscarHistorico"

    payload = "dominio="+Patente+"&limite=5&codigoPais=AR&="
    headers = {
        "cookie": "JSESSIONID=B544913AE18097DC002DA2F72AC68FA6",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:108.0) Gecko/20100101 Firefox/108.0",
        "Accept": "text/javascript, text/html, application/xml, text/xml, */*",
        "Accept-Language": "es-AR,es;q=0.8,en-US;q=0.5,en;q=0.3",
        "Accept-Encoding": "gzip, deflate, br",
        "X-Requested-With": "XMLHttpRequest",
        "X-Prototype-Version": "1.6.1",
        "Content-type": "application/x-www-form-urlencoded; charset=UTF-8",
        "Origin": "https://rto.cent.gov.ar",
        "Connection": "keep-alive",
        "Referer": "https://rto.cent.gov.ar/rto/",
        "Cookie": cookie,
        "Sec-Fetch-Dest": "empty",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Site": "same-origin",
        "TE": "trailers"
    }

    response = requests.request("POST", url, data=payload, headers=headers)
    #print response text (test)
    #print(response.text)
    soup=BeautifulSoup(response.text,'lxml')

# %% [markdown]
# Limpiar soup para historico de revisiones

# %%
def clean_data(tags_hist_revisiones):# returns a list of values: tags
        tags_datos=soup.select(tags_hist_revisiones) #data is inside the tag td
        global datos
        datos=[] 
        for data in tags_datos:
            datos.append(data.get_text(strip=True)) #make a list with the values 
        return(datos)

# %% [markdown]
# Crear lista de diccionarios de historico de revisiones:cada diccionario es una fila

# %%
def create_rows_hist(Patente):
    global df
    global rows
    num_row=int(len(datos)/7)#cantidad de filas(row). cada fila tiene 7 elementos
    for i in range(0,num_row):
        i*=7
        dic={'Dominio':Patente,
            'Planilla':datos[1+i].replace('.',''),
            'Taller':int(datos[0+i]),
            'Tipo Uso':datos[2+i],
            'Fecha':datos[3+i],
            'Resultado':datos[4+i],
            'Versión RTO':datos[5+i]
            }
        rows.append(dic)

# %% [markdown]
# Crear dataframe (df) de historico de revisiones

# %%
def create_df_hist():# returns a dataframe df 
    global df 
    df=pd.DataFrame(rows)
    return(df)

# %% [markdown]
# Utilizando las funciones anteriores. las unimos en una unica funcion. Iteramos en la lista de Patentes

# %%
def scrape(Patentes):
    global rows
    rows=[]
    tags_hist_revisiones='td'#tag de historico de revisiones
    for Patente in tqdm(Patentes):
        get_detalles(str(Patente))
        clean_data(tags_hist_revisiones)
        create_rows_hist(Patente)
    create_df_hist()# returns dataframe df
    return(df['Planilla'].nunique())

# %% [markdown]
# Guardar los dataframes en archivos .csv

# %%
def to_csv(num):
    filename=str(num)+'planillas.hist'
    df.to_csv(filename)

# %% [markdown]
# Dividimos la lista de patentes en N listas. En caso de error no perdemos todo

# %%
def div_lista(Patentes,part):
    global patentes_part
    n=int(len(Patentes)/part)
    patentes_part=[patentes[i:i+n]for i in range(0,len(patentes),n)]
    return(patentes_part)

# %% [markdown]
# Definimos una nueva funcion Scrape que crea un csv por cada particion de la lista de planillas. Esto nos ayuda a no tener que comenzar de 0 si el server se cae o se corta internet

# %%
def scrape_part(Patentes,part,start):
    div_lista(Patentes,part)
    for i in tqdm(range(0+start,part)):
        scrape(patentes_part[i])
        to_csv(i)

# %% [markdown]
# Definimos una funcion para unir los archivos csv en un unico Dataframe y guardar como csv

# %%
def join_csv(part):
    global df_hist
    global planillas_hist
    planillas_hist=pd.DataFrame()
    for i in range(0,part):
        df_hist=pd.read_csv(str(i)+'planillas.hist',index_col=0)
        planillas_hist=pd.concat([planillas_hist,df_hist])
    planillas_hist.to_csv('0.0.planillas.hist.COMPLETE')

# %% [markdown]
# # Actualizar cookie

# %%
cookie="JSESSIONID=73DD0C000F144D328BDC83B6EDD489BA"

# %% [markdown]
# # Lista de PATENTES

# %%
patentes=planillas.sort_values(by=['Dominio'])['Dominio'].str.replace('*','',regex=False).unique().tolist()
patentes
# Out:
# ['AA000HG',
#  'AA001GK',
#  'AA001HU',
#  'AA001IV',
#  'AA001JB',
#  'AA001KB',
#  'AA003PS',
#  'AA004EO',
#  'AA004GI',
#  'AA004GO',
#  'AA004HC',
#  'AA004HM',
#  'AA004IB',
#  'AA004IF',
#  'AA004II',
#  'AA004IJ',
#  'AA004IK',
#  'AA004IL',
#  'AA004IP',
#  'AA004IR',
#  'AA004IS',
#  'AA004IT',
#  'AA004IW',
#  'AA004IX',
#  'AA004IZ',
#  'AA006PE',
#  'AA006PG',
#  'AA006PI',
#  'AA006PJ',
#  'AA006PL',
#  'AA006PN',
#  'AA006PT',
#  'AA006PU',
#  'AA006PZ',
#  'AA008LW',
#  'AA009KB',
#  'AA009SY',
#  'AA013ZE',
#  'AA017XT',
#  'AA017ZP',
#  'AA018NH',
#  'AA018OY',
#  'AA019LN',
#  'AA019LY',
#  'AA019RW',
#  'AA021ZA',
#  'AA021ZB',
#  'AA021ZF',
#  'AA021ZK',
#  'AA021ZX',
#  'AA025BE',
#  'AA025BF',
#  'AA025BK',
#  'AA025BM',
#  'AA025BN',
#  'AA025BR',
#  'AA025BT',
#  'AA025BX',
#  'AA025BZ',
#  'AA025UC',
#  'AA025ZH',
#  'AA028QR',
#  'AA029YS',
#  'AA030AB',
#  'AA030AC',
#  'AA030AF',
#  'AA030AI',
#  'AA030AJ',
#  'AA030AK',
#  'AA030AP',
#  'AA030AQ',
#  'AA030AT',
#  'AA030AU',
#  'AA030AY',
#  'AA030XW',
#  'AA034GI',
#  'AA034HK',
#  'AA035FA',
#  'AA035FK',
#  'AA035GE',
#  'AA035GO',
#  'AA035JB',
#  'AA035JI',
#  'AA035JM',
#  'AA035JN',
#  'AA035JQ',
#  'AA035JS',
#  'AA035JV',
#  'AA035JY',
#  'AA035JZ',
#  'AA035KF',
#  'AA035KI',
#  'AA035KJ',
#  'AA035KK',
#  'AA035KL',
#  'AA035KQ',
#  'AA035KR',
#  'AA035KS',
#  'AA035KW',
#  'AA035KX',
#  'AA039RD',
#  'AA040AQ',
#  'AA040UY',
#  'AA040WX',
#  'AA040YC',
#  'AA040YD',
#  'AA040YE',
#  'AA040YG',
#  'AA040YH',
#  'AA040YI',
#  'AA040YJ',
#  'AA040YK',
#  'AA040YL',
#  'AA040YM',
#  'AA040YQ',
#  'AA040YR',
#  'AA040YT',
#  'AA040YV',
#  'AA041FR',
#  'AA043OB',
#  'AA044FN',
#  'AA044GA',
#  'AA044GE',
#  'AA044GG',
#  'AA044GH',
#  'AA044GI',
#  'AA044GJ',
#  'AA044GK',
#  'AA044GN',
#  'AA044GP',
#  'AA044GV',
#  'AA044GW',
#  'AA044GY',
#  'AA044GZ',
#  'AA044HA',
#  'AA044HB',
#  'AA044HD',
#  'AA044HF',
#  'AA044HJ',
#  'AA044HK',
#  'AA044HL',
#  'AA044HM',
#  'AA044HN',
#  'AA044HO',
#  'AA044HP',
#  'AA044HY',
#  'AA044HZ',
#  'AA044IH',
#  'AA044IP',
#  'AA044IU',
#  'AA045OW',
#  'AA046IB',
#  'AA046IF',
#  'AA046IG',
#  'AA046IH',
#  'AA046II',
#  'AA046IM',
#  'AA046IN',
#  'AA046IO',
#  'AA046IP',
#  'AA046IR',
#  'AA046IZ',
#  'AA046JD',
#  'AA046JG',
#  'AA046JH',
#  'AA046JI',
#  'AA046JK',
#  'AA046JQ',
#  'AA046JU',
#  'AA046JW',
#  'AA046KA',
#  'AA046KF',
#  'AA046KL',
#  'AA046KN',
#  'AA046KO',
#  'AA046KQ',
#  'AA046KS',
#  'AA046KV',
#  'AA046KX',
#  'AA046LA',
#  'AA046LB',
#  'AA046LC',
#  'AA046LD',
#  'AA046LJ',
#  'AA046LM',
#  'AA046LN',
#  'AA046LR',
#  'AA046LS',
#  'AA046LV',
#  'AA046MA',
#  'AA046MC',
#  'AA046MD',
#  'AA046ME',
#  'AA046MF',
#  'AA046MH',
#  'AA046MP',
#  'AA046MR',
#  'AA046MT',
#  'AA046MY',
#  'AA046NE',
#  'AA046NK',
#  'AA046NN',
#  'AA046NO',
#  'AA046NP',
#  'AA046NS',
#  'AA046NT',
#  'AA046NY',
#  'AA046NZ',
#  'AA046OA',
#  'AA046OB',
#  'AA046OC',
#  'AA046OG',
#  'AA046OI',
#  'AA046OJ',
#  'AA046OK',
#  'AA046OL',
#  'AA046OM',
#  'AA046OP',
#  'AA046OW',
#  'AA046OX',
#  'AA047PJ',
#  'AA047WJ',
#  'AA048TH',
#  'AA048UQ',
#  'AA048XE',
#  'AA048XL',
#  'AA048XN',
#  'AA048XQ',
#  'AA048XY',
#  'AA049BK',
#  'AA049SY',
#  'AA054UF',
#  'AA054UK',
#  'AA054UY',
#  'AA054ZZ',
#  'AA055AD',
#  'AA056AX',
#  'AA056CO',
#  'AA059TF',
#  'AA059TG',
#  'AA059TM',
#  'AA059TS',
#  'AA059UQ',
#  'AA059US',
#  'AA059VN',
#  'AA059VO',
#  'AA059XN',
#  'AA059XP',
#  'AA059YG',
#  'AA059ZB',
#  'AA059ZI',
#  'AA060BC',
#  'AA060BE',
#  'AA060BI',
#  'AA060BJ',
#  'AA060BK',
#  'AA060BM',
#  'AA060BN',
#  'AA060BS',
#  'AA060BT',
#  'AA060BU',
#  'AA060CA',
#  'AA060CB',
#  'AA060CD',
#  'AA060CE',
#  'AA060CF',
#  'AA060CG',
#  'AA060CK',
#  'AA060CO',
#  'AA060CP',
#  'AA060CS',
#  'AA060CU',
#  'AA060CW',
#  'AA060CX',
#  'AA060DC',
#  'AA060DN',
#  'AA060DR',
#  'AA060DW',
#  'AA060DZ',
#  'AA060NA',
#  'AA060NP',
#  'AA061NT',
#  'AA062KD',
#  'AA065ON',
#  'AA066GL',
#  'AA066SD',
#  'AA068OS',
#  'AA068PG',
#  'AA068RE',
#  'AA068UE',
#  'AA068UR',
#  'AA068UX',
#  'AA068UY',
#  'AA068VB',
#  'AA068VS',
#  'AA068VZ',
#  'AA068WG',
#  'AA068XF',
#  'AA068YE',
#  'AA073DW',
#  'AA076WM',
#  'AA078KE',
#  'AA078MV',
#  'AA080OZ',
#  'AA083MF',
#  'AA083MG',
#  'AA083MK',
#  'AA083MS',
#  'AA083MT',
#  'AA083MU',
#  'AA083MX',
#  'AA083MY',
#  'AA083NA',
#  'AA083NG',
#  'AA083NH',
#  'AA083NJ',
#  'AA083NK',
#  'AA083NM',
#  'AA083NP',
#  'AA083NQ',
#  'AA083NR',
#  'AA083NW',
#  'AA083NY',
#  'AA088LL',
#  'AA088LM',
#  'AA088QP',
#  'AA088QS',
#  'AA088RQ',
#  'AA088SC',
#  'AA088SE',
#  'AA088SF',
#  'AA088SG',
#  'AA088SI',
#  'AA088SM',
#  'AA088SP',
#  'AA088SU',
#  'AA088TG',
#  'AA088TW',
#  'AA088VC',
#  'AA088VD',
#  'AA088VE',
#  'AA088VF',
#  'AA088VG',
#  'AA088VH',
#  'AA088VM',
#  'AA088VN',
#  'AA088VQ',
#  'AA088VU',
#  'AA088VV',
#  'AA088VX',
#  'AA088WB',
#  'AA088WC',
#  'AA088WD',
#  'AA088WE',
#  'AA088WI',
#  'AA088WN',
#  'AA088WO',
#  'AA088WW',
#  'AA088WY',
#  'AA088XA',
#  'AA088XB',
#  'AA088XD',
#  'AA088XE',
#  'AA088XG',
#  'AA088XH',
#  'AA088XL',
#  'AA088XP',
#  'AA088XR',
#  'AA088XS',
#  'AA088XT',
#  'AA088XW',
#  'AA088XY',
#  'AA088YB',
#  'AA088YD',
#  'AA088YP',
#  'AA088YQ',
#  'AA088YS',
#  'AA088YV',
#  'AA088YW',
#  'AA088YX',
#  'AA088YZ',
#  'AA089OH',
#  'AA089VR',
#  'AA092AM',
#  'AA092XP',
#  'AA092YQ',
#  'AA092YT',
#  'AA092ZB',
#  'AA092ZC',
#  'AA092ZD',
#  'AA092ZF',
#  'AA092ZG',
#  'AA092ZH',
#  'AA092ZJ',
#  'AA092ZQ',
#  'AA092ZR',
#  'AA092ZV',
#  'AA093AB',
#  'AA093AC',
#  'AA093AD',
#  'AA093AH',
#  'AA093AI',
#  'AA093AJ',
#  'AA093AO',
#  'AA093AQ',
#  'AA093AS',
#  'AA093AT',
#  'AA093AV',
#  'AA093AY',
#  'AA093AZ',
#  'AA098VM',
#  'AA098VO',
#  'AA099JA',
#  'AA099JC',
#  'AA099JF',
#  'AA101GM',
#  'AA101GP',
#  'AA102BW',
#  'AA103IT',
#  'AA105AC',
#  'AA105AD',
#  'AA105AF',
#  'AA105AK',
#  'AA105AM',
#  'AA105AN',
#  'AA105AU',
#  'AA105AY',
#  'AA105AZ',
#  'AA105BF',
#  'AA105BG',
#  'AA105BH',
#  'AA105BJ',
#  'AA105BK',
#  'AA105BL',
#  'AA105BR',
#  'AA105CA',
#  'AA105CB',
#  'AA105CE',
#  'AA105CF',
#  'AA105CG',
#  'AA105CH',
#  'AA105CJ',
#  'AA105CK',
#  'AA105CL',
#  'AA105CO',
#  'AA105CP',
#  'AA105CQ',
#  'AA105CR',
#  'AA105CS',
#  'AA105CW',
#  'AA105CY',
#  'AA105CZ',
#  'AA105DC',
#  'AA105DD',
#  'AA105DG',
#  'AA105DL',
#  'AA105DM',
#  'AA105DS',
#  'AA105DU',
#  'AA105DV',
#  'AA105DW',
#  'AA105DX',
#  'AA107KK',
#  'AA110VD',
#  'AA110VE',
#  'AA110VN',
#  'AA110VP',
#  'AA110WN',
#  'AA110XE',
#  'AA110YC',
#  'AA110YD',
#  'AA110YE',
#  'AA110YG',
#  'AA110YH',
#  'AA110YK',
#  'AA110YM',
#  'AA110YO',
#  'AA110YQ',
#  'AA110YS',
#  'AA110YV',
#  'AA110YW',
#  'AA110YY',
#  'AA110ZB',
#  'AA110ZD',
#  'AA110ZE',
#  'AA110ZF',
#  'AA110ZJ',
#  'AA110ZM',
#  'AA110ZP',
#  'AA110ZQ',
#  'AA110ZR',
#  'AA110ZV',
#  'AA110ZX',
#  'AA110ZZ',
#  'AA111FV',
#  'AA112MR',
#  'AA114AX',
#  'AA116CL',
#  'AA116DE',
#  'AA116DF',
#  'AA116DI',
#  'AA116DJ',
#  'AA116DL',
#  'AA116DM',
#  'AA116DO',
#  'AA116DP',
#  'AA116DY',
#  'AA116DZ',
#  'AA116OU',
#  'AA122UV',
#  'AA122WS',
#  'AA125JQ',
#  'AA126DE',
#  'AA127FE',
#  'AA127FG',
#  'AA127FH',
#  'AA127FK',
#  'AA127FP',
#  'AA127FR',
#  'AA127FU',
#  'AA127GB',
#  'AA127GD',
#  'AA127GJ',
#  'AA127GK',
#  'AA127GM',
#  'AA127GO',
#  'AA127GV',
#  'AA127GZ',
#  'AA127HD',
#  'AA127HE',
#  'AA127HH',
#  'AA127HI',
#  'AA127HK',
#  'AA127HO',
#  'AA127HP',
#  'AA127HQ',
#  'AA127HR',
#  'AA127HS',
#  'AA127HT',
#  'AA127HV',
#  'AA127HW',
#  'AA127HX',
#  'AA127HY',
#  'AA127HZ',
#  'AA127IC',
#  'AA127ID',
#  'AA127IE',
#  'AA127IF',
#  'AA127IG',
#  'AA127IH',
#  'AA127IK',
#  'AA127IL',
#  'AA127IP',
#  'AA127IQ',
#  'AA127IU',
#  'AA127IY',
#  'AA127JB',
#  'AA127JD',
#  'AA127JJ',
#  'AA127JM',
#  'AA127JN',
#  'AA127JO',
#  'AA127JR',
#  'AA127JS',
#  'AA127JV',
#  'AA127JW',
#  'AA127JY',
#  'AA127KB',
#  'AA127KD',
#  'AA127KF',
#  'AA127KJ',
#  'AA127KM',
#  'AA127KN',
#  'AA127KP',
#  'AA127KR',
#  'AA127KU',
#  'AA127KY',
#  'AA127KZ',
#  'AA127LB',
#  'AA127LD',
#  'AA127LE',
#  'AA127LG',
#  'AA127LH',
#  'AA127LL',
#  'AA127LM',
#  'AA127LN',
#  'AA127LR',
#  'AA127LS',
#  'AA127LX',
#  'AA127LZ',
#  'AA127MA',
#  'AA127MB',
#  'AA127MI',
#  'AA127MJ',
#  'AA127MP',
#  'AA127MR',
#  'AA127MS',
#  'AA127MZ',
#  'AA127QO',
#  'AA132FF',
#  'AA132TH',
#  'AA133RQ',
#  'AA133SK',
#  'AA133SU',
#  'AA133UB',
#  'AA133UD',
#  'AA133UE',
#  'AA133UF',
#  'AA133UG',
#  'AA133UN',
#  'AA133UP',
#  'AA133UR',
#  'AA133US',
#  'AA133UT',
#  'AA133UW',
#  'AA133UX',
#  'AA133UZ',
#  'AA133VA',
#  'AA133VB',
#  'AA133VF',
#  'AA133VH',
#  'AA133VJ',
#  'AA133VQ',
#  'AA133VR',
#  'AA133VS',
#  'AA133VT',
#  'AA133VX',
#  'AA133VZ',
#  'AA133WB',
#  'AA133WD',
#  'AA133WJ',
#  'AA133WT',
#  'AA133WZ',
#  'AA133XF',
#  'AA133XL',
#  'AA133XO',
#  'AA133XP',
#  'AA133XT',
#  'AA133XW',
#  'AA133XX',
#  'AA133XY',
#  'AA133XZ',
#  'AA133YC',
#  'AA133YE',
#  'AA133YG',
#  'AA133YH',
#  'AA133YJ',
#  'AA133YM',
#  'AA133YO',
#  'AA133YP',
#  'AA133YQ',
#  'AA133YR',
#  'AA133YU',
#  'AA133YW',
#  'AA133YX',
#  'AA133YY',
#  'AA138FK',
#  'AA138FL',
#  'AA138HA',
#  'AA138HC',
#  'AA138HM',
#  'AA138HZ',
#  'AA138IC',
#  'AA138IZ',
#  'AA138JA',
#  'AA138JB',
#  'AA138JE',
#  'AA138JN',
#  'AA138JO',
#  'AA138JQ',
#  'AA138JX',
#  'AA138KA',
#  'AA138KF',
#  'AA138KV',
#  'AA142MF',
#  'AA143HW',
#  'AA143RH',
#  'AA152JF',
#  'AA152KE',
#  'AA152KH',
#  'AA152KI',
#  'AA152KM',
#  'AA152KO',
#  'AA152KR',
#  'AA152KT',
#  'AA152KU',
#  'AA152KW',
#  'AA152KX',
#  'AA152LA',
#  'AA152LF',
#  'AA152LG',
#  'AA152LI',
#  'AA152LK',
#  'AA152LO',
#  'AA152LP',
#  'AA152LR',
#  'AA152LS',
#  'AA152LU',
#  'AA152LW',
#  'AA152LX',
#  'AA152LY',
#  'AA152LZ',
#  'AA152ZB',
#  'AA153GM',
#  'AA156ED',
#  'AA156EF',
#  'AA156FF',
#  'AA156FR',
#  'AA156GM',
#  'AA156HU',
#  'AA156KL',
#  'AA156KP',
#  'AA156LG',
#  'AA156LI',
#  'AA156MC',
#  'AA156ML',
#  'AA156MS',
#  'AA156ND',
#  'AA156OA',
#  'AA156OC',
#  'AA156OF',
#  'AA156OH',
#  'AA156OJ',
#  'AA156OL',
#  'AA156OP',
#  'AA156OT',
#  'AA156OZ',
#  'AA156PD',
#  'AA156PE',
#  'AA156PH',
#  'AA156PI',
#  'AA156PJ',
#  'AA156PM',
#  'AA156PN',
#  'AA156PO',
#  'AA156PR',
#  'AA156PT',
#  'AA156PW',
#  'AA156PY',
#  'AA157RF',
#  'AA159XN',
#  'AA160DV',
#  'AA160MU',
#  'AA160NA',
#  'AA160ND',
#  'AA160NF',
#  'AA160NH',
#  'AA160NI',
#  'AA160NJ',
#  'AA160NN',
#  'AA160NO',
#  'AA160NP',
#  'AA160NR',
#  'AA160NS',
#  'AA160NT',
#  'AA160NY',
#  'AA160NZ',
#  'AA160OA',
#  'AA160OB',
#  'AA160OD',
#  'AA160OE',
#  'AA160OF',
#  'AA160OG',
#  'AA160OL',
#  'AA160OM',
#  'AA160OQ',
#  'AA160OS',
#  'AA160OU',
#  'AA160OV',
#  'AA160OW',
#  'AA160PA',
#  'AA160PB',
#  'AA160PD',
#  'AA160PE',
#  'AA160PF',
#  'AA160PI',
#  'AA160PL',
#  'AA160PM',
#  'AA160PS',
#  'AA160PW',
#  'AA160PX',
#  'AA160PY',
#  'AA160UV',
#  'AA165QS',
#  'AA165RF',
#  'AA166IO',
#  'AA167ID',
#  'AA167MM',
#  'AA167MO',
#  'AA167NS',
#  'AA167NT',
#  'AA167RA',
#  'AA168DH',
#  'AA168EZ',
#  'AA170LA',
#  'AA173VA',
#  'AA174ML',
#  'AA174MT',
#  'AA174NB',
#  'AA174NR',
#  'AA175KS',
#  'AA178SM',
#  'AA178UB',
#  'AA178UC',
#  'AA178UD',
#  'AA178UG',
#  'AA178UH',
#  'AA178UK',
#  'AA178UO',
#  'AA178UR',
#  'AA178US',
#  'AA178UW',
#  'AA178UZ',
#  'AA178VA',
#  'AA178VH',
#  'AA178VI',
#  'AA178VJ',
#  'AA178VQ',
#  'AA178VR',
#  'AA178VU',
#  'AA178WA',
#  'AA178WC',
#  'AA178WH',
#  'AA178WK',
#  'AA178WL',
#  'AA178WM',
#  'AA178WO',
#  'AA178WP',
#  'AA178WS',
#  'AA178WU',
#  'AA178WY',
#  'AA178WZ',
#  'AA178XG',
#  'AA178XH',
#  'AA178XI',
#  'AA178XL',
#  'AA178XM',
#  'AA178XP',
#  'AA178XV',
#  'AA178XW',
#  'AA178XX',
#  'AA180JY',
#  'AA181MW',
#  'AA182SY',
#  'AA183GL',
#  'AA183GV',
#  'AA183HU',
#  'AA183HX',
#  'AA183LI',
#  'AA183LX',
#  'AA183MH',
#  'AA183NA',
#  'AA183NB',
#  'AA183NC',
#  'AA183ND',
#  'AA183NE',
#  'AA183NG',
#  'AA183NH',
#  'AA183NN',
#  'AA183NP',
#  'AA183NR',
#  'AA183NT',
#  'AA183NY',
#  'AA185OP',
#  'AA186EW',
#  'AA187CG',
#  'AA187CH',
#  'AA187CJ',
#  'AA187CK',
#  'AA187CM',
#  'AA187CN',
#  'AA187CQ',
#  'AA187CX',
#  'AA187DA',
#  'AA187DD',
#  'AA187DF',
#  'AA187DG',
#  'AA187DH',
#  'AA187DI',
#  'AA187DK',
#  'AA187DL',
#  'AA187DM',
#  'AA187DN',
#  'AA187DP',
#  'AA187DU',
#  'AA187DZ',
#  'AA187EA',
#  'AA187EB',
#  'AA187EE',
#  'AA187EF',
#  'AA187EH',
#  'AA187EZ',
#  'AA187FC',
#  'AA187FE',
#  'AA187FG',
#  'AA187FH',
#  'AA187FM',
#  'AA187FO',
#  'AA187FR',
#  'AA187FS',
#  'AA187FT',
#  'AA187FV',
#  'AA187FY',
#  'AA187FZ',
#  'AA187MF',
#  'AA191GF',
#  'AA192BB',
#  'AA192BF',
#  'AA192BG',
#  'AA192BH',
#  'AA192BJ',
#  'AA192BN',
#  'AA192BO',
#  'AA192BP',
#  'AA192BW',
#  'AA192BX',
#  'AA192CD',
#  'AA192CJ',
#  'AA192CM',
#  'AA192CN',
#  'AA192CO',
#  'AA192CR',
#  'AA192CU',
#  'AA192CZ',
#  'AA192DA',
#  'AA192DB',
#  'AA192DC',
#  'AA192DD',
#  'AA192DM',
#  'AA192DQ',
#  'AA192DR',
#  'AA192DY',
#  'AA192EG',
#  'AA192EM',
#  'AA192EP',
#  'AA192ET',
#  'AA192EZ',
#  'AA192YT',
#  'AA195UA',
#  'AA195UE',
#  'AA199MT',
#  'AA199PD',
#  'AA199UI',
#  'AA200OG',
#  'AA200OG(E)',
#  'AA200RL',
#  'AA200RP',
#  'AA202BU',
#  'AA202BV',
#  'AA202CB',
#  'AA202JN',
#  'AA203CR',
#  'AA204MB',
#  'AA204MC',
#  'AA204MD',
#  'AA204MF',
#  'AA204MI',
#  'AA204ML',
#  'AA204MR',
#  'AA204MS',
#  'AA204MT',
#  'AA204MW',
#  'AA204MZ',
#  'AA204NA',
#  'AA204NC',
#  'AA204NG',
#  'AA204NH',
#  'AA204NL',
#  'AA204NM',
#  'AA204NN',
#  'AA204NO',
#  'AA204NR',
#  'AA204NS',
#  'AA204NU',
#  'AA204NV',
#  'AA204NW',
#  'AA204NX',
#  'AA204NZ',
#  'AA204OB',
#  'AA204OJ',
#  'AA204OO',
#  'AA204OS',
#  'AA204OU',
#  'AA204OX',
#  'AA204OY',
#  'AA204PA',
#  'AA204PB',
#  'AA204PD',
#  'AA204PF',
#  'AA204PG',
#  'AA204PI',
#  'AA204PJ',
#  'AA204PL',
#  'AA204PQ',
#  'AA204PS',
#  'AA204PX',
#  'AA204PZ',
#  'AA205ZP',
#  'AA207OA',
#  'AA207OC',
#  ...]

# %% [markdown]
# # Scrape Particiones

# %%
scrape_part(patentes,30,7)
# Out:
#   0%|          | 0/23 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]
#   0%|          | 0/2561 [00:00<?, ?it/s]

# %% [markdown]
# # Verificar dataframe creado

# %%
df_hist=pd.read_csv(str(29)+'planillas.hist',index_col=0)

# %%
df_hist
# Out:
#       Dominio  Planilla  Taller Tipo Uso       Fecha    Resultado  Versión RTO
# 0      SHV097   1073263     108       GC  09/11/2018         Apto         2014
# 1      SHV097   1071955     108       GC  19/10/2018  Condicional         2014
# 2      SHV097   1048019     108       GC  13/10/2017         Apto         2014
# 3      SHV097   1037324     108       GC  13/04/2017         Apto         2014
# 4      SHV097   1023982      65       GC  18/10/2016         Apto         2014
# ...       ...       ...     ...      ...         ...          ...          ...
# 11690  XOO415   1037818       4       PX  19/08/2016         Apto         2014
# 11691  XOO981   1074450       4       PX  17/04/2018         Apto         2014
# 11692  XOS697   1039212       4       PX  13/09/2016         Apto         2014
# 11693  XOS702   1052067       4       PX  01/04/2017  Condicional         2014
# 11694  XOX629   1146886       4       PX  01/10/2021         Apto         2014
#
# [11695 rows x 7 columns]

# %% [markdown]
# En caso de no completar . Ejecutar de nuevo la funcion scrape_part pero modificandola para comenzar desde la ultima particion hecha correctamente

# %% [markdown]
# # Unir las particiones en un unico archivo CSV

# %%
join_csv(30)

# %% [markdown]
# # Leer CSV completo y analizar

# %%
planillas_hist=pd.read_csv('0.0.planillas.hist.COMPLETE',index_col=0)
planillas_hist
# Out:
#        Dominio  Planilla  Taller Tipo Uso       Fecha    Resultado  \
# 0      AA000HG   1173505       4       PX  14/11/2022         Apto
# 1      AA000HG   1124182       4       PX  05/11/2020         Apto
# 2      AA000HG   1053004      65       PX  04/09/2018         Apto
# 3      AA001GK   1154432       4       PX  13/01/2022         Apto
# 4      AA001GK   1066213      65       PX  07/01/2020         Apto
# ...        ...       ...     ...      ...         ...          ...
# 11690   XOO415   1037818       4       PX  19/08/2016         Apto
# 11691   XOO981   1074450       4       PX  17/04/2018         Apto
# 11692   XOS697   1039212       4       PX  13/09/2016         Apto
# 11693   XOS702   1052067       4       PX  01/04/2017  Condicional
# 11694   XOX629   1146886       4       PX  01/10/2021         Apto
#
#        Versión RTO
# 0             2014
# 1             2014
# 2             2014
# 3             2014
# 4             2014
# ...            ...
# 11690         2014
# 11691         2014
# 11692         2014
# 11693         2014
# 11694         2014
#
# [265738 rows x 7 columns]

# %%
planillas_hist.nunique()
# Out:
# Dominio         76341
# Planilla       206842
# Taller            127
# Tipo Uso           10
# Fecha            5132
# Resultado           4
# Versión RTO         2
# dtype: int64

# %%
planillas_hist.value_counts()
# Out:
# Dominio  Planilla  Taller  Tipo Uso  Fecha       Resultado    Versión RTO
# VXX178   133229    4       GC        17/06/2014  Apto         2003           2
# JWX562   133047    4       GC        13/06/2014  Condicional  2003           2
# GQZ837   56083     124     GC        28/06/2010  Condicional  2003           2
# WXY049   133048    4       GC        13/06/2014  Apto         2003           2
# HHY320   124968    82      GC        18/11/2010  Apto         2003           2
#                                                                             ..
# GWO018   1010950   4       PX        30/04/2015  Apto         2014           1
#          1101292   4       PX        08/08/2019  Apto         2014           1
#          1125877   4       PX        01/12/2020  Apto         2014           1
#          1251379   123     PX        20/12/2021  Apto         2014           1
# XOX629   1146886   4       PX        01/10/2021  Apto         2014           1
# Length: 265724, dtype: int64

# %%
planillas_hist[planillas_hist['Dominio']=='JWX562']
# Out:
#      Dominio  Planilla  Taller Tipo Uso       Fecha    Resultado  Versión RTO
# 7408  JWX562   1017577       4       GC  01/09/2015         Apto         2014
# 7409  JWX562    133313       4       GC  18/06/2014         Apto         2003
# 7410  JWX562    133047       4       GC  13/06/2014  Condicional         2003
# 7411  JWX562    133047       4       GC  13/06/2014  Condicional         2003

# %% [markdown]
# # LISTA DE PLANILLAS CON CODIGO DE TALLER- PARA USAR EN EL SCRAPE DE DETALLES Y ANOMALIAS

# %%
planillas_lista=df.loc[:,['Planilla','Taller']]
planillas_lista

# %%
planillas_lista.values.tolist()

# %%
planillas_lista

# %%
planillas['Fecha'][planillas['Fecha_date']>'2022-03-01']
